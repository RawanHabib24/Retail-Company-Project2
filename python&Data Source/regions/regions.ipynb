# %%
import pandas as pd

# %%
regions = pd.read_csv('Region.csv')
regions
# Out:
#      region_id sales_district    sales_region
# 0            1  San Francisco    Central West
# 1            2    Mexico City  Mexico Central
# 2            3    Los Angeles      South West
# 3            4    Guadalajara     Mexico West
# 4            5      Vancouver     Canada West
# ..         ...            ...             ...
# 104        105       Victoria     Canada West
# 105        106    Mexico City  Mexico Central
# 106        107    Mexico City  Mexico Central
# 107        108    Mexico City  Mexico Central
# 108        109    Mexico City  Mexico Central
#
# [109 rows x 3 columns]

# %%
regions.isna().sum()
# Out:
# region_id         0
# sales_district    0
# sales_region      0
# dtype: int64

# %%
regions.drop_duplicates(inplace=True)

# %%
regions['sales_district'].unique()
# Out:
# <StringArray>
# ['San Francisco',   'Mexico City',   'Los Angeles',   'Guadalajara',
#      'Vancouver',      'Victoria',     'San Diego',       'Seattle',
#       'Portland',         'Salem',       'Orizaba',       'Hidalgo',
#         'Marida',       'Camacho',      'Acapulco',      'Tlaxiaco',
#      'Bremerton',    'Bellingham',        'Tacoma',       'Spokane',
#    'Walla Walla',        'Yakima']
# Length: 22, dtype: str

# %%
regions['sales_region'].unique()
# Out:
# <StringArray>
# [  'Central West', 'Mexico Central',     'South West',    'Mexico West',
#     'Canada West',     'North West',   'Mexico South']
# Length: 7, dtype: str

# %%
regions.to_csv('C:\\Users\\Lenovo\\Desktop\\Analysis Projects\\retail company\\cleaned datasets\\regions.csv', index=False)
