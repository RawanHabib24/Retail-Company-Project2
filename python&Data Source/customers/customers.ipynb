# %%
import pandas as pd
import numpy as np

# %%
customers = pd.read_csv("Customers.csv")
customers
# Out:
#        customer_id  customer_acct_num first_name  last_name  \
# 0                1        87462024688      Sheri     Nowmer
# 1                2        87470586299    Derrick    Whelply
# 2                3        87475757600     Jeanne      Derry
# 3                4        87500482201    Michael     Spence
# 4                5        87514054179       Maya  Gutierrez
# ...            ...                ...        ...        ...
# 10276        10277        87439274191       Fran       Ross
# 10277        10278        87448420500     Myreda    Calahoo
# 10278        10279        87453135848       Mary      Ayers
# 10279        10280        87458639740     Ernest     Aiello
# 10280        10281        87460163235     Samuel    Cartney
#
#             customer_address  customer_city customer_state_province  \
# 0           2433 Bailey Road       Tlaxiaco                  Oaxaca
# 1         2219 Dewing Avenue          Sooke                      BC
# ...

# %%
customers.shape
# Out:
# (10281, 20)

# %%
customers.isna().sum()
# Out:
# customer_id                0
# customer_acct_num          0
# first_name                 0
# last_name                  1
# customer_address           0
# customer_city              0
# customer_state_province    0
# customer_postal_code       0
# customer_country           0
# birthdate                  0
# marital_status             0
# yearly_income              0
# gender                     0
# total_children             0
# num_children_at_home       0
# education                  0
# acct_open_date             0
# member_card                0
# occupation                 0
# homeowner                  0
# dtype: int64

# %% [markdown]
# customer_id is the primary key

# %%
customers.duplicated(subset='customer_id').sum()
# Out:
# np.int64(0)

# %%
customers.loc[customers['last_name'].isna()==True, ['last_name']] = customers.loc[customers['last_name'].isna()==True, ['last_name']].fillna('')

# %%
customers.isna().sum()
# Out:
# customer_id                0
# customer_acct_num          0
# first_name                 0
# last_name                  0
# customer_address           0
# customer_city              0
# customer_state_province    0
# customer_postal_code       0
# customer_country           0
# birthdate                  0
# marital_status             0
# yearly_income              0
# gender                     0
# total_children             0
# num_children_at_home       0
# education                  0
# acct_open_date             0
# member_card                0
# occupation                 0
# homeowner                  0
# dtype: int64

# %% [markdown]
# check data types

# %%
customers.dtypes
# Out:
# customer_id                int64
# customer_acct_num          int64
# first_name                   str
# last_name                    str
# customer_address             str
# customer_city                str
# customer_state_province      str
# customer_postal_code       int64
# customer_country             str
# birthdate                    str
# marital_status               str
# yearly_income                str
# gender                       str
# total_children             int64
# num_children_at_home       int64
# education                    str
# acct_open_date               str
# member_card                  str
# occupation                   str
# homeowner                    str
# dtype: object

# %% [markdown]
# concatenate first name and last name

# %%
customers['full_name'] = customers['first_name'] + ' ' + customers['last_name']

# %%
customers.to_csv('C:\\Users\\Lenovo\\Desktop\\Analysis Projects\\retail company\\cleaned datasets\\customers.csv', index=False)
